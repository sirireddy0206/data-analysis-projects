# %% [markdown]
# Dataset Description:
#
# The dataset contains 86 entries and 12 columns.
# The "Total" column seems to represent the total marks.
# Other columns represent marks for different questions, with scores ranging across different maximum marks.

# %%
import pandas as pd
df = pd.read_csv("class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
df['Q1'] = df['Q1aM4'] + df['Q1bM6']
df['Q2'] = df['Q2aM6'] + df['Q2bM4']
df['Q3'] = df['Q3aM5'] + df['Q3bM5']
df['Q4'] = df['Q4aM3'] + df['Q4bM7']
df['Q5'] = df['Q5M10']
df['Q6'] = df['Q6aM4'] + df['Q6bM6']

df.drop(['Q1aM4', 'Q1bM6', 'Q2aM6', 'Q2bM4', 'Q3aM5', 'Q3bM5', 'Q4aM3', 'Q4bM7', 'Q5M10', 'Q6aM4', 'Q6bM6'], axis=1, inplace=True)
df.head()
# Out:
#    Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0     37   9.0  10.0   3.0  NaN   8.0  10.0
# 1     32   7.0   7.0   NaN  9.0   9.0   NaN
# 2     33   9.0   6.0  10.0  NaN   8.0   NaN
# 3     24  10.0   9.0   4.0  NaN   NaN   NaN
# 4     36   9.0   8.0   9.0  NaN  10.0   NaN

# %% [markdown]
#  ## Checking Missing Value

# %%
df.isnull().sum()
# Out:
# Total     0
# Q1       13
# Q2       16
# Q3       39
# Q4       64
# Q5       30
# Q6       60
# dtype: int64

# %% [markdown]
# ## Fill Missing Values

# %%
df.fillna(df.mean(), inplace=True)
df
# Out:
#     Total         Q1    Q2         Q3        Q4    Q5         Q6
# 0      37   9.000000  10.0   3.000000  7.590909   8.0  10.000000
# 1      32   7.000000   7.0   8.489362  9.000000   9.0   8.769231
# 2      33   9.000000   6.0  10.000000  7.590909   8.0   8.769231
# 3      24  10.000000   9.0   4.000000  7.590909   8.0   8.769231
# 4      36   9.000000   8.0   9.000000  7.590909  10.0   8.769231
# ..    ...        ...   ...        ...       ...   ...        ...
# 81     32   9.000000   7.0   8.000000  7.590909   8.0  10.000000
# 82     27   4.000000   8.0   8.489362  7.590909   7.0   8.000000
# 83     37  10.000000   8.0   8.489362  7.590909   9.0  10.000000
# 84     28   8.164384   9.0   9.000000  7.590909   6.0   8.769231
# 85     29  10.000000   8.6   8.489362  8.000000   7.0   5.000000
#
# [86 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Total    0
# Q1       0
# Q2       0
# Q3       0
# Q4       0
# Q5       0
# Q6       0
# dtype: int64

# %% [markdown]
# ## Scores in descending order

# %%
top_scorer = df[df['Total'] == df['Total'].max()]
df
# Out:
#     Total         Q1    Q2         Q3        Q4    Q5         Q6
# 0      37   9.000000  10.0   3.000000  7.590909   8.0  10.000000
# 1      32   7.000000   7.0   8.489362  9.000000   9.0   8.769231
# 2      33   9.000000   6.0  10.000000  7.590909   8.0   8.769231
# 3      24  10.000000   9.0   4.000000  7.590909   8.0   8.769231
# 4      36   9.000000   8.0   9.000000  7.590909  10.0   8.769231
# ..    ...        ...   ...        ...       ...   ...        ...
# 81     32   9.000000   7.0   8.000000  7.590909   8.0  10.000000
# 82     27   4.000000   8.0   8.489362  7.590909   7.0   8.000000
# 83     37  10.000000   8.0   8.489362  7.590909   9.0  10.000000
# 84     28   8.164384   9.0   9.000000  7.590909   6.0   8.769231
# 85     29  10.000000   8.6   8.489362  8.000000   7.0   5.000000
#
# [86 rows x 7 columns]

# %% [markdown]
# ## Rounding-off the values

# %%
columns_to_round = ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']
df[columns_to_round] = df[columns_to_round].round()
df
# Out:
#     Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37   9.0  10.0   3.0  8.0   8.0  10.0
# 1      32   7.0   7.0   8.0  9.0   9.0   9.0
# 2      33   9.0   6.0  10.0  8.0   8.0   9.0
# 3      24  10.0   9.0   4.0  8.0   8.0   9.0
# 4      36   9.0   8.0   9.0  8.0  10.0   9.0
# ..    ...   ...   ...   ...  ...   ...   ...
# 81     32   9.0   7.0   8.0  8.0   8.0  10.0
# 82     27   4.0   8.0   8.0  8.0   7.0   8.0
# 83     37  10.0   8.0   8.0  8.0   9.0  10.0
# 84     28   8.0   9.0   9.0  8.0   6.0   9.0
# 85     29  10.0   9.0   8.0  8.0   7.0   5.0
#
# [86 rows x 7 columns]

# %%
top_5_per_question = {}


for column in df.columns[1:]:
    top_5_per_question[column] = df.nlargest(5, column)


print(top_5_per_question["Q1"])
df
# Out:
#     Total    Q1    Q2    Q3   Q4   Q5   Q6
# 3      24  10.0   9.0   4.0  8.0  8.0  9.0
# 5      20  10.0  10.0   8.0  8.0  8.0  9.0
# 7      34  10.0  10.0   8.0  8.0  8.0  9.0
# 14     30  10.0   8.0   9.0  8.0  8.0  9.0
# 21     34  10.0   8.0  10.0  8.0  8.0  9.0
#     Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37   9.0  10.0   3.0  8.0   8.0  10.0
# 1      32   7.0   7.0   8.0  9.0   9.0   9.0
# 2      33   9.0   6.0  10.0  8.0   8.0   9.0
# 3      24  10.0   9.0   4.0  8.0   8.0   9.0
# 4      36   9.0   8.0   9.0  8.0  10.0   9.0
# ..    ...   ...   ...   ...  ...   ...   ...
# 81     32   9.0   7.0   8.0  8.0   8.0  10.0
# 82     27   4.0   8.0   8.0  8.0   7.0   8.0
# 83     37  10.0   8.0   8.0  8.0   9.0  10.0
# 84     28   8.0   9.0   9.0  8.0   6.0   9.0
# 85     29  10.0   9.0   8.0  8.0   7.0   5.0
#
# [86 rows x 7 columns]

# %% [markdown]
# ## Average Scores for Each Question

# %%
import matplotlib.pyplot as plt


average_scores = df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']].mean()


average_scores.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Average Scores per Question")
plt.xlabel("Questions")
plt.ylabel("Average Score")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ## Distribution of Total Scores

# %%
df['Total'].plot(kind='hist', bins=10, color='orange', edgecolor='black', alpha=0.7)
plt.title("Distribution of Total Scores")
plt.xlabel("Total Scores")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### The histogram displays the distribution of "Total Scores," with the x-axis representing score ranges (bins) and the y-axis showing their frequency. Each orange bar reflects how many scores fall within a specific range. The graph provides a visual overview of how the scores are distributed across the dataset.

# %% [markdown]
# ## Score Spread per Question

# %%
import seaborn as sns

sns.boxplot(data=df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']])
plt.title("Score Spread per Question")
plt.xlabel("Questions")
plt.ylabel("Scores")
plt.show()

# %% [markdown]
# ### The boxplot shows the distribution of scores for each question (Q1–Q6), highlighting the median, interquartile range (IQR), and spread. Outliers are represented as individual points beyond the whiskers. It provides a clear comparison of score variability and central tendency across the questions.

# %% [markdown]
# ## Students Scoring Full Marks in Any Question

# %%
full_marks = df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']].apply(lambda row: any(row == 10), axis=1).sum()
no_full_marks = len(df) - full_marks

data = [full_marks, no_full_marks]
labels = ['Full Marks in Any Question', 'No Full Marks']

plt.pie(data, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#8da0cb', '#e78ac3'])
plt.title("Proportion of Students Scoring Full Marks")
plt.show()

# %% [markdown]
# ### The pie chart shows the proportion of students who scored full marks (10) in any question versus those who didn't. A significant portion is highlighted for students who achieved full marks in at least one question, while the rest represents those who did not. This visualization helps compare the prevalence of perfect scores among the students.

# %% [markdown]
# ## From highest to lowest in order

# %%
df_sorted = df.sort_values(by='Total', ascending=False)


df_sorted
# Out:
#     Total    Q1    Q2    Q3    Q4    Q5    Q6
# 73     40  10.0   9.0  10.0   8.0  10.0  10.0
# 51     40   8.0  10.0   8.0  10.0  10.0   9.0
# 53     40  10.0  10.0  10.0   8.0  10.0   9.0
# 65     40  10.0  10.0  10.0   8.0  10.0   9.0
# 33     40   8.0  10.0  10.0  10.0   8.0  10.0
# ..    ...   ...   ...   ...   ...   ...   ...
# 57     17   8.0   9.0   8.0  10.0   8.0   9.0
# 22     14   8.0   7.0   8.0   8.0   8.0   9.0
# 23      9   7.0   9.0   8.0   8.0   8.0   2.0
# 11      8   4.0   9.0   8.0   8.0   8.0   9.0
# 69      3   8.0   9.0   8.0   8.0   8.0   9.0
#
# [86 rows x 7 columns]

# %% [markdown]
# ## Average Performance for All Questions

# %%
average_scores = df[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']].mean()
print(average_scores)
# Out:
# Q1    8.139535
# Q2    8.674419
# Q3    8.267442
# Q4    7.895349
# Q5    8.000000
# Q6    8.930233
# dtype: float64

# %% [markdown]
# ##  Question-Wise Toppers

# %%
toppers = {}
for col in ['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']:
    toppers[col] = df[df[col] == df[col].max()].index.tolist()

print("Question-wise Toppers:", toppers)
# Out:
# Question-wise Toppers: {'Q1': [3, 5, 7, 14, 21, 26, 32, 35, 40, 42, 53, 65, 67, 68, 70, 73, 80, 83, 85], 'Q2': [0, 5, 7, 10, 13, 16, 17, 19, 28, 32, 33, 35, 36, 37, 38, 40, 42, 45, 46, 47, 49, 51, 53, 55, 59, 61, 62, 64, 65, 68, 70, 71, 74, 78], 'Q3': [2, 6, 9, 15, 20, 21, 24, 27, 28, 33, 36, 42, 45, 46, 47, 49, 50, 53, 54, 59, 62, 64, 65, 70, 71, 73, 78], 'Q4': [15, 33, 47, 51, 56, 57, 72], 'Q5': [4, 28, 32, 36, 37, 44, 47, 49, 51, 53, 55, 59, 65, 67, 73], 'Q6': [0, 9, 10, 15, 17, 26, 33, 50, 54, 55, 56, 59, 61, 73, 81, 83]}

# %% [markdown]
# ## Total Scores bar plot

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=df.index, y="Total", data=df, palette="viridis")
plt.title("Total Scores of Students")
plt.xlabel("Student Index")
plt.ylabel("Total Score")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\VINITHA\AppData\Local\Temp\ipykernel_12428\1322711161.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df.index, y="Total", data=df, palette="viridis")

# %% [markdown]
# ### The bar plot displays the total scores of students, with each bar representing an individual student's total score. The variation in bar heights shows the differences in total performance across students, highlighting those with higher or lower scores. The x-axis (student index) is rotated for readability, allowing a clear comparison of total scores.

# %% [markdown]
# ## Score Distribution Boxplot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df.iloc[:, 1:], palette="pastel")
plt.title("Score Distribution Across Questions")
plt.xlabel("Questions")
plt.ylabel("Scores")
plt.show()

# %% [markdown]
# ### The boxplot shows the distribution of scores across different questions, with each box representing a question's score spread. It highlights the median score, interquartile range (IQR), and potential outliers for each question. This visualization allows comparison of score variability and central tendencies across the questions, identifying which have more consistent or dispersed scores.

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(10, 6))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix of Scores")
plt.show()

# %% [markdown]
# ### The heatmap shows the correlation between different score variables, with color intensity indicating the strength of the relationship. High positive or negative correlations are easily identifiable, helping to understand how scores across different questions are related.

# %% [markdown]
# ##  Pie Chart showing Average Scores by Question

# %%
average_scores = df.iloc[:, 1:].mean()
plt.figure(figsize=(8, 8))
plt.pie(average_scores, labels=average_scores.index, autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Question-Wise Average Scores")
plt.show()

# %% [markdown]
# ### The pie chart illustrates the proportion of average scores for each question, with each segment representing the contribution of a question to the total average score. It helps in visualizing which questions have higher or lower average scores relative to others.

# %% [markdown]
# ##  Distribution of the Total Score Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["Total"], kde=True, bins=8, color="skyblue")
plt.title("Distribution of Total Scores")
plt.xlabel("Total Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### The histogram with a KDE curve shows the distribution of total scores, providing insights into the frequency of different score ranges. The shape of the curve helps identify whether the scores are normally distributed or skewed

# %% [markdown]
# ***Dataset Observations
#
# Total Marks Distribution
#
# The total marks range from 3 to 40, with an average of 29.36.
# Most students scored between 25 and 36, indicating a fairly consistent performance.
#
# Performance on Individual Questions
#
# Q1aM4 & Q1bM6:
# Students generally performed well, with most scoring close to the maximum.
# Q2aM6 & Q2bM4:
# Q2aM6 has a higher average (5.29 out of 6), suggesting students found it easier.
# Q3aM5 & Q3bM5:
# Many missing values, but students who answered scored around 4 out of 5.
# Q4aM3 & Q4bM7:
# Fewer responses, especially in Q4bM7, indicating it might be an optional or difficult question.
# Q5M10:
# High scores overall (average: 8 out of 10), suggesting students performed well.
# Q6aM4 & Q6bM6:
# Lower number of responses, but scores are mostly above average.
#
# Missing Data Issues
#
# Some questions (Q3, Q4, Q6) have significant missing values, which might indicate:
# * Optional questions
# * Data entry issues
# * Students skipping certain questions
